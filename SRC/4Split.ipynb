# %%
import sys
from tqdm import tqdm

import re
from deep_translator import GoogleTranslator
from nlp_id.lemmatizer import Lemmatizer 
from sklearn.feature_extraction.text import TfidfVectorizer

import pandas as pd
import numpy as np

from imblearn.over_sampling import SMOTE

# %%
df_handled =  pd.read_csv("../Temp/cleaned_datav2_translated_lemarized_stopwords_Handled.csv").iloc[:,1:]

# %%
df_handled
# Out:
#                                                    text  \
# 0     kunjung prabowo resmi serah proyek bantu air b...
# 1     anies tepuk tangan riah rektor wajib mata kuli...
# 2     emng bener sih dukung goblok dukung hnya sj ri...
# 3     anies nyata kritis kerja prabowo anggap engga ...
# 4     anies baswedan harap asn masuk tni polri pegan...
# ...                                                 ...
# 4263  ngeliat debat kemaren pas prabowo kicep keluar...
# 4264  masyarakat prabowo gibran milik visi jalan asp...
# 4265  imo irasional irasional tbh lurus anies ahok k...
# 4266  lihat ganjar kecimpung lgislatif eksekutif bhk...
# 4267  acara masak calon presiden nomor urut habis in...
#
#                         label
# 0            Sumber Daya Alam
# 1                     Politik
# 2                   Demografi
# 3                     Politik
# 4                     Politik
# ...                       ...
# 4263                  Politik
# 4264                  Politik
# 4265                  Ekonomi
# 4266  Pertahanan dan Keamanan
# 4267         Sumber Daya Alam
#
# [4268 rows x 2 columns]
